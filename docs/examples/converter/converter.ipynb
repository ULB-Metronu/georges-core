# %% [markdown]
# # Converter

# %%
import georges_core
from georges_core.units import ureg as _

# %% [markdown]
# ## Load a MAD-X Twiss file

# %%
madx_line = georges_core.sequences.TwissSequence(path='MADX',
                                                 filename='twiss_madx.tfs',
                                                 with_units=True,
                                                 with_beam=True, 
                                                 nparticles=100
                                                )

# %% [markdown]
# ## Load a MAD-NG Twiss file
#
# As the particle is not (yet) written in the header os the Twiss file, you must define the particle name and its kinematics for MAD-G Twiss file. Moreover, you have to specify the lines to skip when you read the Twiss file.

# %%
kin = georges_core.Kinematics(140 * _.MeV)

# %%
mad_line = georges_core.sequences.TwissSequence(path='MADNG',
                                                filename='twiss_madng.tfs',
                                                with_units=True,
                                                lines=34,
                                                with_beam=False,
                                                kinematics=kin)

# %% [markdown]
# ## Load a Tranport file

# %% [markdown]
# ### 2 flavors are available:
# * TransportInputIBAFlavor: from Transport file generated by IBA
# * TransportInputOriginalFlavor: original Transport file

# %%
transport_line = georges_core.sequences.TransportSequence(path='TRANSPORT',
                                                          filename = 'calc.bml', 
                                                          flavor=georges_core.codes_io.transport.TransportInputIBAFlavor)

# %% [markdown]
# ## Load a BDSIM output file

# %%
bdsim_line = georges_core.sequences.BDSIMSequence(path='BDSIM', filename='output.root')
# Out:
# /Users/rtesse/.pyenv/versions/georges_core/lib/python3.8/site-packages/pybdsim/Convert/_BdsimPrimaries2Inrays.py:7: UserWarning:
#
# ROOT not available - some functionality missing
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/nl/fwq_43rd6h74bj5p6q3qn7rm0000gn/T/ipykernel_73323/4112298656.py in <module>
# ----> 1 bdsim_line = georges_core.sequences.BDSIMSequence(path='BDSIM', filename='output.root')
#
# ~/reps/ULB-Metronu/python_libs/georges-core/georges-core-src/georges_core/sequences/sequence.py in __init__(self, filename, path, from_element, to_element)
#     838         """
#     839         # The pybdsim import is made inside the class init to avoid a pybdsim ( and then ROOT ) dependence when it is not needed.
# --> 840         from pybdsim.Analysis import BDSimOutput
#     841
#     842         # Load the model
#
# ModuleNotFoundError: No module named 'pybdsim.Analysis'

# %%
beam = bdsim_line.metadata.data['BEAM_DISTRIBUTION']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nl/fwq_43rd6h74bj5p6q3qn7rm0000gn/T/ipykernel_73323/2621728234.py in <module>
# ----> 1 beam = bdsim_line.metadata.data['BEAM_DISTRIBUTION']
#
# NameError: name 'bdsim_line' is not defined

# %% [markdown]
# ## Load a CSV file (survey file)

# %%
survey_line = georges_core.sequences.SurveySequence(path='CSV', filename="survey.csv")
survey_line.expand(); # This must be done before tracking !
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/nl/fwq_43rd6h74bj5p6q3qn7rm0000gn/T/ipykernel_73323/1855016365.py in <module>
# ----> 1 survey_line = georges_core.sequences.SurveySequence(path='CSV', filename="survey.csv")
#       2 survey_line.expand(); # This must be done before tracking !
#
# AttributeError: module 'georges_core.sequences' has no attribute 'SurveySequence'
